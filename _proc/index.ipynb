# %% [raw]
# ---
# description: A sample of how to create a deck of cards lib using nbdev
# output-file: index.html
# title: nbdev_cards
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# A deck of cards demo of [nbdev](https://nbdev.fast.ai) based on ideas from [Think Python 2nd Edition](https://greenteapress.com/wp/think-python-2e/) by Allen B. Downey.

# %% [markdown]
# ## Install

# %% [markdown]
# Install using:
#
#     pip install nbdev-cards
#
# or:
#
#     conda install -c fastai nbdev-cards

# %% [markdown]
# ## How to use

# %% [markdown]
# This lib provides a [`Card`](https://.github.io/nbdev_cards_tutorial/card.html#card) class you can use to create, display, and compare playing cards:

# %%
Card(1,3)
# Out:
# 3♦️

# %% [markdown]
# Suits are numbered according to this list:

# %%
suits
# Out:
# ['♣️', '♦️', '❤️', '♠️']
